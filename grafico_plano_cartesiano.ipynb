# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/lp20231/blob/main/grafico_plano_cartesiano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.xlim([-10, 10])
plt.ylim(-10, 10)
plt.show()

# %%
# Adicionar linha paralela ao eixo y
plt.axvline(x=0, color='r', linestyle='--')

# Adicionar linha paralela ao eixo x
plt.axhline(y=0, color='r', linestyle='--')

plt.xlim([-10, 10])
plt.ylim(-10, 10)
plt.show()

# %%
# Adicionar linha paralela ao eixo y
plt.axvline(x=0, color='r', linestyle='--')

# Adicionar linha paralela ao eixo x
plt.axhline(y=0, color='r', linestyle='--')

plt.xlim([-10, 10])
plt.ylim(-10, 10)

x = np.linspace(-10, 10, 100)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

class Grafico:
    def __init__(self):
        self.x = None
        self.y = None

    def criar_eixo_x(self, inicio, passo, fim):
        self.x = np.linspace(inicio, passo, fim)

    def calcular_y(self, funcao):
        self.y = funcao(self.x)

    def configura_limites_dos_eixos(self, limite_inferior_x=None, limite_superior_x=None, limite_inferior_y=None, limite_superior_y=None):
        if ((limite_inferior_x is not None) and (limite_superior_x is not None) and (limite_inferior_y is not None) and (limite_superior_y is not None)):
            plt.xlim([limite_inferior_x, limite_superior_x])
            plt.ylim([limite_inferior_y, limite_superior_y])

    def configura_titulo_e_rotulos(self, titulo=None, rotulo_x=None, rotulo_y=None):
        if titulo is not None:
            plt.title(titulo)
        if rotulo_x is not None:
            plt.xlabel(rotulo_x)
        if rotulo_y is not None:
            plt.ylabel(rotulo_y)

    def exibir_gráfico(self):
        # Adicionar linha paralela ao eixo y
        plt.axvline(x=0, color='r', linestyle='--')
        # Adicionar linha paralela ao eixo x
        plt.axhline(y=0, color='r', linestyle='--')
        plt.plot(self.x, self.y)
        plt.show()

# %%
# Exemplo de uso da classe Gráfico
grafico_seno = Grafico()
grafico_seno.criar_eixo_x(-10, 10, 100)
grafico_seno.calcular_y(np.sin)  # Exemplo de uso da função seno do numpy
grafico_seno.configura_titulo_e_rotulos(titulo='Curva senoidal', rotulo_x='x', rotulo_y='y')
limite_inferior=-10
limite_superior=10
grafico_seno.configura_limites_dos_eixos(limite_inferior_x=limite_inferior, limite_superior_x=limite_superior, limite_inferior_y=limite_inferior, limite_superior_y=limite_superior)
grafico_seno.exibir_gráfico()
