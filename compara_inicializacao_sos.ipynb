# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/lp20231/blob/main/compara_inicializacao_sos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html_content = '''
<!DOCTYPE html>
<html>
<head>
  <style>
    table {{
      border-collapse: collapse;
      width: 100%;
    }}
    th, td {{
      text-align: left;
      padding: 8px;
    }}
    tr:nth-child(even){{background-color: #f2f2f2}}
    th {{
      background-color: #4CAF50;
      color: white;
    }}
  </style>
</head>
<body>
  <h2>Comparativo dos Passos de Inicialização</h2>
  <table>
    <tr>
      <th>Passos de Inicialização</th>
      <th>Windows 10</th>
      <th>Linux Ubuntu Desktop</th>
      <th>macOS Mojave</th>
    </tr>
    <tr>
      <td>Inicialização do hardware</td>
      <td>BIOS/UEFI realiza o POST</td>
      <td>BIOS/UEFI realiza o POST</td>
      <td>BIOS/UEFI realiza o POST</td>
    </tr>
    <tr>
      <td>Carregamento do bootloader</td>
      <td>Carrega o Windows Boot Manager</td>
      <td>Carrega o GRUB (Grand Unified Bootloader)</td>
      <td>Carrega o Apple Bootloader (EFI Bootloader)</td>
    </tr>
    <tr>
      <td>Kernel do sistema operacional</td>
      <td>Carrega o kernel do Windows</td>
      <td>Carrega o kernel do Linux</td>
      <td>Carrega o kernel do macOS</td>
    </tr>
    <tr>
      <td>Inicialização em modo de texto</td>
      <td>Mostra a tela de inicialização do Windows</td>
      <td>Mostra a tela de inicialização do Linux</td>
      <td>Mostra mensagens de inicialização em modo texto</td>
    </tr>
    <tr>
      <td>Inicialização do ambiente gráfico</td>
      <td>Inicia o Windows Shell (explorer.exe)</td>
      <td>Inicia o servidor gráfico X11 ou Wayland</td>
      <td>Inicia o WindowServer e o ambiente gráfico Aqua</td>
    </tr>
    <tr>
      <td>Tela de login</td>
      <td>Exibe a tela de login do Windows</td>
      <td>Exibe a tela de login do Linux</td>
      <td>Exibe a tela de login do macOS</td>
    </tr>
    <tr>
      <td>Inicialização da Área de Trabalho</td>
      <td>Carrega a Área de Trabalho do Windows</td>
      <td>Carrega a Área de Trabalho do ambiente de desktop escolhido (por exemplo, GNOME, KDE)</td>
      <td>Carrega a Área de Trabalho do macOS</td>
    </tr>
    <tr>
      <td>Inicialização de serviços e aplicativos</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
    </tr>
    <tr>
      <td>Sistema operacional pronto</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
    </tr>
  </table>
</body>
</html>
'''

# %%
html_content2 = '''
<!DOCTYPE html>
<html>
<head>
  <style>
    table {
      border-collapse: collapse;
      width: 100%;
    }
    th, td {
      text-align: left;
      padding: 8px;
      border: 1px solid #ddd;
    }
    tr:nth-child(even) {
      background-color: #f2f2f2;
    }
    th {
      background-color: #4CAF50;
      color: white;
    }
  </style>
</head>
<body>
  <h2>Comparativo dos Passos de Inicialização do Sistema Operacional (Desktop)</h2>
  <table>
    <tr style="background-color: #e0e0e0;">
      <th>Passos de Inicialização</th>
      <th>Windows 10</th>
      <th>Linux Ubuntu Desktop</th>
      <th>macOS Mojave</th>
    </tr>
    <tr>
      <td>Inicialização do hardware</td>
      <td>BIOS/UEFI realiza o POST</td>
      <td>BIOS/UEFI realiza o POST</td>
      <td>BIOS/UEFI realiza o POST</td>
    </tr>
    <tr>
      <td>Carregamento do bootloader</td>
      <td>Carrega o Windows Boot Manager</td>
      <td>Carrega o GRUB (Grand Unified Bootloader)</td>
      <td>Carrega o Apple Bootloader (EFI Bootloader)</td>
    </tr>
    <tr>
      <td>Kernel do sistema operacional</td>
      <td>Carrega o kernel do Windows</td>
      <td>Carrega o kernel do Linux</td>
      <td>Carrega o kernel do macOS</td>
    </tr>
    <tr>
      <td>Inicialização em modo de texto</td>
      <td>Mostra a tela de inicialização do Windows</td>
      <td>Mostra a tela de inicialização do Linux</td>
      <td>Mostra mensagens de inicialização em modo texto</td>
    </tr>
    <tr>
      <td>Inicialização do ambiente gráfico</td>
      <td>Inicia o Windows Shell (explorer.exe)</td>
      <td>Inicia o servidor gráfico X11 ou Wayland</td>
      <td>Inicia o WindowServer e o ambiente gráfico Aqua</td>
    </tr>
    <tr>
      <td>Tela de login</td>
      <td>Exibe a tela de login do Windows</td>
      <td>Exibe a tela de login do Linux</td>
      <td>Exibe a tela de login do macOS</td>
    </tr>
    <tr>
      <td>Inicialização da Área de Trabalho</td>
      <td>Carrega a Área de Trabalho do Windows</td>
      <td>Carrega a Área de Trabalho do ambiente de desktop escolhido (por exemplo, GNOME, KDE)</td>
      <td>Carrega a Área de Trabalho do macOS</td>
    </tr>
    <tr>
      <td>Inicialização de serviços e aplicativos</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
      <td>Inicia serviços e aplicativos definidos na inicialização</td>
    </tr>
    <tr>
      <td>Sistema operacional pronto</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
      <td>Pronto para uso após a conclusão das etapas anteriores</td>
    </tr>
  </table>
</body>
</html>
'''

# %%
with open('comparativo_inicializacao.html', 'w') as file:
    file.write(html_content2)

print("Arquivo HTML criado com sucesso!")
# Out:
# Arquivo HTML criado com sucesso!
